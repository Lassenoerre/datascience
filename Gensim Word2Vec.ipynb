# %% [markdown]
# Import relevant packages:

# %%
from numpy import array
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
import pandas as pd
# Out:
# Using TensorFlow backend.
# C:\Users\frede\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\frede\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\frede\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\frede\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\frede\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\frede\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# Import dataset:

# %%
df = pd.read_csv('articles_all_clean.csv')
df = df[:100]

# %%
df.head()
# Out:
#    Unnamed: 0                                       Title            Topic  \
# 0           0       Shopping Malls Tracking Holiday Sales     Street Signs
# 1           1                 Consumers Adore Gift Cards         U.S. News
# 2           2                  Whats Wrong With Wal-Mart?     Street Signs
# 3           3                           Shape Up Ship Out  Holiday Central
# 4           4  Big Box Boom: Gadgets Sell And Prices Boil  Holiday Central
#
#          Date                                            Content  \
# 0  27-11-2006  Its not only retailers who are closely watchin...
# 1  27-11-2006  The National Retail Federations Holiday Consum...
# 2  27-11-2006  Despite the fine weather in much of the nation...
# 3  27-11-2006  It helped nail the coffin shut on eToys. Its t...
# 4  27-11-2006  Theres plenty of time to shop for Christmas ri...
#
#                                                 Link  \
# 0  https://www.cnbc.com/2006/11/27/shopping-malls...
# 1  https://www.cnbc.com/2006/11/27/consumers-ador...
# 2  https://www.cnbc.com/2006/11/27/whats-wrong-wi...
# 3  https://www.cnbc.com/2006/11/27/shape-up-ship-...
# 4  https://www.cnbc.com/2006/11/27/big-box-boom-g...
#
#                                               tokens  \
# 0  ['retailer', 'closely', 'watch', 'holiday', 'r...
# 1  ['national', 'retail', 'federations', 'holiday...
# 2  ['fine', 'weather', 'nation', 'large', 'retail...
# 3  ['help', 'nail', 'coffin', 'shut', 'etoys', 'g...
# 4  ['plenty', 'time', 'shop', 'caveat', 'procrast...
#
#                                       clean_articles
# 0  retailer closely watch holiday receipt mall ow...
# 1  national retail federations holiday consumer i...
# 2  fine weather nation large retailer dark cloud ...
# 3  help nail coffin shut etoys great equalizer br...
# 4  plenty time shop caveat procrastinator flat sc...

# %% [markdown]
# ## Define x and y variables:

# %% [markdown]
# Define y:

# %% [markdown]
# Define x by converting the column with article tokens to a list of strings:

# %%
train_docs = df["clean_articles"].astype('str').tolist()

# %%
print(train_docs)
# Out:
# ['retailer closely watch holiday receipt mall owner keenly interested line depend today street signs cnbc speak man know truth chief large mall company nation president general growth properties say business mall strong sale average increase year date say traffic extremely good electronic sell briskly apparel toysmichael say weakness consumer chief operating office taubman agree add home sector little weak mall story', 'national retail federations holiday consumer intentions actions survey say popularity gift card increase remarkable rate hit record level thank partly personalization option available retailer trade group survey conduct bigresearch find gift card sale increase sale record average consumer spend gift card average accord survey separate survey deloitte touche show consumer buy gift card average card person compare gift card take lot stress holiday shopping make favorite people age say vice president strategy bigresearch stand gift addition gift basket gift card fickle people holiday shopping list electronic retail giant best buy circuit city heavy gift card activity consumer purchase big ticket item plasma television electronic gift account quarter holiday sale accord consumer electronics association cell phone game console lead pack nrf holiday consumer intentions actions survey conduct poll consumer poll margin error', 'fine weather nation large retailer dark cloud closing bell cnbcs find miss exclusive interview rochdale investments fund manager challenge face wal mart store sale fall low gas price help kind price cut necessary turn cnbc answer', 'help nail coffin shut etoys great equalizer brick click retail shipping postal service satisfy demand united parcel service fedex see opportunity join popular lexicon economic fact patti freeman jupiter research tell expect web sale jump big brown brace million online acquire gift package flow shipping center sprawl ups facility cnbcs visit ups plant southwest chicago inside look mind boggle scope holiday good traffic survey commission company conclude internet consumer declare positive delivery experience inspire return online store future number high business ebay will test ups mettle partner home shopping network qvc handle literally million qvc order reach package accord shipper let game begin', 'plenty time shop caveat procrastinator flat screen tv thanksgiving weekend warn trouble gargantuan television prohibitive trade tariff enact ahead nancy pelosis assumption power fcc declare entertainment unit legal call big box store get scarce price leap expect bad run yuletide report best buy paramus metro area denizen rush buy holiday goody tell gang squawk box inventory giant tv set maraud black friday crowd point specifically panasonic flat screen go onslaught baby run say big victor win association mighty mite make tiny powerful radio speaker gadget sounddock gear boom tune apple computers ipod digital frontier living room electronic pump sale brick mortar crowd snap videogame console sonys playstation disappear shopper demand tepid review weird winner rovell little irony consumer patience dispense hand gratification shop site ebay batch supposedly sell price microchip mega toy actually drop course store boost price wal mart stylish niche late feature snazzy designer dud humble price go successful root trumpet sudden price cut consumer electronic strategy help world big retailer reverse decline spell woe like best buy circuit city', 'london oil price edge higher saudi arabias oil minister say opec cut outputfurther meet dollar slide low europrovide support commodity complex itencouraged fund seek alternative investment analyst say uncertainty technical weakness limit gain oil crude trade high barrel gmt london brent crude fall oil underdog commodity moment saidolivi jakob petromatrix fundamental notclear rise crude inventory push price lowerlast open outcry trade new yorkbefore thanksgiving holiday future trade electronically high stock level worry organization the ...

# %%
size = len(train_docs)
# Out:
# 100

# %%
import gensim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-e70e92d32c6e> in <module>
# ----> 1 import gensim
#
# ~\Anaconda3\lib\site-packages\gensim\__init__.py in <module>
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# ~\Anaconda3\lib\site-packages\gensim\parsing\__init__.py in <module>
#       2
#       3 from .porter import PorterStemmer  # noqa:F401
# ----> 4 from .preprocessing import (remove_stopwords, strip_punctuation, strip_punctuation2,  # noqa:F401
#       5                             strip_tags, strip_short, strip_numeric,
#       6                             strip_non_alphanum, strip_multiple_whitespaces,
#
# ~\Anaconda3\lib\site-packages\gensim\parsing\preprocessing.py in <module>
#      40 import glob
#      41
# ---> 42 from gensim import utils
#      43 from gensim.parsing.porter import PorterStemmer
#      44
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in <module>
#      43 from six.moves import range
#      44
# ---> 45 from smart_open import open
#      46
#      47 from multiprocessing import cpu_count
#
# ImportError: cannot import name 'open' from 'smart_open' (C:\Users\frede\Anaconda3\lib\site-packages\smart_open\__init__.py)

# %% [markdown]
# Train word2vec model:

# %%
model = gensim.models.Word2Vec(sentences = train_docs, size = size, window = 5, workers = 4, min_count = 1)
# Vocab size:
words = list(model.wv.vocab)
print('vocabulary size: %d' % len(words))

# %% [markdown]
# Test the model:

# %%
model.wv.most_similar('stock')

# %% [markdown]
# Set the vocabulary size to the number of tokens in our vocabulary:

# %%
from keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
#num_words = vocab_size
tokenizer.fit_on_texts(train_docs)

# %%
sequences = tokenizer.texts_to_sequences(train_docs)

# %%
tokenizer.index_word
# Out:
# {1: 'say',
#  2: 'sale',
#  3: 'market',
#  4: 'price',
#  5: 'high',
#  6: 'report',
#  7: 'expect',
#  8: 'rise',
#  9: 'rate',
#  10: 'company',
#  11: 'fall',
#  12: 'share',
#  13: 'home',
#  14: 'store',
#  15: 'new',
#  16: 'low',
#  17: 'stock',
#  18: 'economic',
#  19: 'growth',
#  20: 'consumer',
#  21: 'analyst',
#  22: 'close',
#  23: 'economy',
#  24: 'housing',
#  25: 'oil',
#  26: 'inflation',
#  27: 'fed',
#  28: 'business',
#  29: 'cut',
#  30: 'good',
#  31: 'datum',
#  32: 'big',
#  33: 'decline',
#  34: 'large',
#  35: 'time',
#  36: 'sell',
#  37: 'tell',
#  38: 'gain',
#  39: 'increase',
#  40: 'look',
#  41: 'drop',
#  42: 'forecast',
#  43: 'street',
#  44: 'buy',
#  45: 'investment',
#  46: 'spending',
#  47: 'estimate',
#  48: 'interest',
#  49: 'remain',
#  50: 'come',
#  51: 'bank',
#  52: 'strong',
#  53: 'group',
#  54: 'wal',
#  55: 'see',
#  56: 'point',
#  57: 'cnbcs',
#  58: 'dollar',
#  59: 'york',
#  60: 'chief',
#  61: 'retailer',
#  62: 'accord',
#  63: 'sector',
#  64: 'help',
#  65: 'number',
#  66: 'department',
#  67: 'federal',
#  68: 'deal',
#  69: 'index',
#  70: 'reserve',
#  71: 'chairman',
#  72: 'average',
#  73: 'retail',
#  74: 'level',
#  75: 'power',
#  76: 'energy',
#  77: 'product',
#  78: 'wall',
#  79: 'investor',
#  80: 'cost',
#  81: 'comment',
#  82: 'economist',
#  83: 'go',
#  84: 'slow',
#  85: 'weak',
#  86: 'demand',
#  87: 'grow',
#  88: 'holiday',
#  89: 'show',
#  90: 'world',
#  91: 'think',
#  92: 'figure',
#  93: 'firm',
#  94: 'people',
#  95: 'mart',
#  96: 'crude',
#  97: 'open',
#  98: 'continue',
#  99: 'offer',
#  100: 'include',
#  101: 'likely',
#  102: 'dolor',
#  103: 'story',
#  104: 'slightly',
#  105: 'earning',
#  106: 'watch',
#  107: 'activity',
#  108: 'news',
#  109: 'give',
#  110: 'expectation',
#  111: 'add',
#  112: 'trade',
#  113: 'spend',
#  114: 'order',
#  115: 'note',
#  116: 'financial',
#  117: 'capital',
#  118: 'fan',
#  119: 'national',
#  120: 'list',
#  121: 'positive',
#  122: 'impact',
#  123: 'have',
#  124: 'overall',
#  125: 'moderate',
#  126: 'profit',
#  127: 'gm',
#  128: 'cnbc',
#  129: 'little',
#  130: 'hit',
#  131: 'take',
#  132: 'lead',
#  133: 'future',
#  134: 'ahead',
#  135: 'bad',
#  136: 'start',
#  137: 'revenue',
#  138: 'end',
#  139: 'pace',
#  140: 'sport',
#  141: 'raise',
#  142: 'line',
#  143: 'make',
#  144: 'get',
#  145: 'inventory',
#  146: 'sign',
#  147: 'believe',
#  148: 'way',
#  149: 'question',
#  150: 'result',
#  151: 'hope',
#  152: 'major',
#  153: 'value',
#  154: 'base',
#  155: 'gasoline',
#  156: 'industry',
#  157: 'survey',
#  158: 'great',
#  159: 'box',
#  160: 'late',
#  161: 'concern',
#  162: 'well',
#  163: 'income',
#  164: 'lunch',
#  165: 'post',
#  166: 'morning',
#  167: 'core',
#  168: 'release',
#  169: 'labor',
#  170: 'operation',
#  171: 'need',
#  172: 'turpis',
#  173: 'tortor',
#  174: 'eu',
#  175: 'purus',
#  176: 'varius',
#  177: 'tempus',
#  178: 'tempor',
#  179: 'diamfaucibus',
#  180: 'pulvinar',
#  181: 'speak',
#  182: 'president',
#  183: 'card',
#  184: 'find',
#  185: 'tv',
#  186: 'run',
#  187: 'meet',
#  188: 'trading',
#  189: 'long',
#  190: 'term',
#  191: 'plan',
#  192: 'real',
#  193: 'book',
#  194: 'slump',
#  195: 'dow',
#  196: 'target',
#  197: 'provide',
#  198: 'loss',
#  199: 'maker',
#  200: 'bid',
#  201: 'credit',
#  202: 'house',
#  203: 'know',
#  204: 'gift',
#  205: 'record',
#  206: 'compare',
#  207: 'weather',
#  208: 'service',
#  209: 'will',
#  210: 'flat',
#  211: 'set',
#  212: 'hold',
#  213: 'meeting',
#  214: 'appear',
#  215: 'follow',
#  216: 'private',
#  217: 'sharply',
#  218: 'predict',
#  219: 'food',
#  220: 'pccw',
#  221: 'electronic',
#  222: 'weakness',
#  223: 'shopping',
#  224: 'game',
#  225: 'united',
#  226: 'opec',
#  227: 'support',
#  228: 'euro',
#  229: 'half',
#  230: 'break',
#  231: 'early',
#  232: 'director',
#  233: 'government',
#  234: 'drag',
#  235: 'bernanke',
#  236: 'slowdown',
#  237: 'risk',
#  238: 'beige',
#  239: 'exchange',
#  240: 'ford',
#  241: 'motor',
#  242: 'states',
#  243: 'shareholder',
#  244: 'auto',
#  245: 'trend',
#  246: 'period',
#  247: 'hybrid',
#  248: 'gdp',
#  249: 'phone',
#  250: 'poll',
#  251: 'online',
#  252: 'squawk',
#  253: 'barrel',
#  254: 'measure',
#  255: 'fuel',
#  256: 'policy',
#  257: 'senior',
#  258: 'especially',
#  259: 'executive',
#  260: 'video',
#  261: 'detail',
#  262: 'outlook',
#  263: 'mixed',
#  264: 'expand',
#  265: 'move',
#  266: 'commerce',
#  267: 'region',
#  268: 'exist',
#  269: 'hong',
#  270: 'global',
#  271: 'worth',
#  272: 'automaker',
#  273: 'european',
#  274: 'speech',
#  275: 'mortgage',
#  276: 'control',
#  277: 'closely',
#  278: 'nation',
#  279: 'year',
#  280: 'agree',
#  281: 'margin',
#  282: 'call',
#  283: 'area',
#  284: 'boost',
#  285: 'producer',
#  286: 'read',
#  287: 'production',
#  288: 'supply',
#  289: 'marts',
#  290: 'sony',
#  291: 'brand',
#  292: 'work',
#  293: 'pressure',
#  294: 'session',
#  295: 'lift',
#  296: 'reflect',
#  297: 'domestic',
#  298: 'air',
#  299: 'stake',
#  300: 'talk',
#  301: 'jersey',
#  302: 'equity',
#  303: 'issue',
#  304: 'want',
#  305: 'improve',
#  306: 'construction',
#  307: 'lose',
#  308: 'indicate',
#  309: 'meat',
#  310: 'general',
#  311: 'association',
#  312: 'closing',
#  313: 'fund',
#  314: 'turn',
#  315: 'research',
#  316: 'reach',
#  317: 'screen',
#  318: 'higher',
#  319: 'probably',
#  320: 'cite',
#  321: 'luxury',
#  322: 'strategist',
#  323: 'leave',
#  324: 'pay',
#  325: 'benefit',
#  326: 'industrial',
#  327: 'nasdaq',
#  328: 'technology',
#  329: 'confidence',
#  330: 'board',
#  331: 'gross',
#  332: 'distillate',
#  333: 'estate',
#  334: 'pfizer',
#  335: 'soft',
#  336: 'cool',
#  337: 'cover',
#  338: 'source',
#  339: 'vehicle',
#  340: 'japanese',
#  341: 'japan',
#  342: 'total',
#  343: 'district',
#  344: 'america',
#  345: 'strength',
#  346: 'thomson',
#  347: 'sit',
#  348: 'city',
#  349: 'bell',
#  350: 'interview',
#  351: 'gas',
#  352: 'opportunity',
#  353: 'digital',
#  354: 'shopper',
#  355: 'review',
#  356: 'winner',
#  357: 'site',
#  358: 'toy',
#  359: 'worry',
#  360: 'bring',
#  361: 'bullish',
#  362: 'central',
#  363: 'factor',
#  364: 'tiffany',
#  365: 'far',
#  366: 'hard',
#  367: 'short',
#  368: 'keep',
#  369: 'case',
#  370: 'money',
#  371: 'stay',
#  372: 'play',
#  373: 'state',
#  374: 'jones',
#  375: 'key',
#  376: 'durable',
#  377: 'stores',
#  378: 'commercial',
#  379: 'lower',
#  380: 'fast',
#  381: 'median',
#  382: 'feds',
#  383: 'plunge',
#  384: 'reuters',
#  385: 'filing',
#  386: 'green',
#  387: 'struggle',
#  388: 'output',
#  389: 'cold',
#  390: 'committee',
#  391: 'overseas',
#  392: 'able',
#  393: 'statement',
#  394: 'solid',
#  395: 'job',
#  396: 'ease',
#  397: 'regulatory',
#  398: 'net',
#  399: 'focus',
#  400: 'competition',
#  401: 'improvement',
#  402: 'beat',
#  403: 'hike',
#  404: 'corporate',
#  405: 'ipsum',
#  406: 'amet',
#  407: 'consectetur',
#  408: 'adipisce',
#  409: 'elit',
#  410: 'malesuada',
#  411: 'ut',
#  412: 'posuere',
#  413: 'dapi',
#  414: 'suscipit',
#  415: 'owner',
#  416: 'today',
#  417: 'man',
#  418: 'favorite',
#  419: 'ticket',
#  420: 'fine',
#  421: 'miss',
#  422: 'face',
#  423: 'shop',
#  424: 'unit',
#  425: 'boom',
#  426: 'hand',
#  427: 'course',
#  428: 'commodity',
#  429: 'push',
#  430: 'day',
#  431: 'decide',
#  432: 'aim',
#  433: 'climb',
#  434: 'nearly',
#  435: 'discount',
#  436: 'announce',
#  437: 'right',
#  438: 'here',
#  439: 'heating',
#  440: 'currency',
#  441: 'hurt',
#  442: 'ipo',
#  443: 'public',
#  444: 'blame',
#  445: 'particular',
#  446: 'negative',
#  447: 'rival',
#  448: 'magazine',
#  449: 'main',
#  450: 'sharp',
#  451: 'revision',
#  452: 'small',
#  453: 'dvd',
#  454: 'produce',
#  455: 'system',
#  456: 'uncomfortably',
#  457: 'soon',
#  458: 'reckson',
#  459: 'securities',
#  460: 'unchanged',
#  461: 'debt',
#  462: 'speculation',
#  463: 'banking',
#  464: 'earlier',
#  465: 'clear',
#  466: 'worker',
#  467: 'compensation',
#  468: 'action',
#  469: 'strike',
#  470: 'effect',
#  471: 'fresh',
#  472: 'bond',
#  473: 'force',
#  474: 'additional',
#  475: 'official',
#  476: 'head',
#  477: 'correction',
#  478: 'live',
#  479: 'american',
#  480: 'teen',
#  481: 'hot',
#  482: 'tivo',
#  483: 'cable',
#  484: 'place',
#  485: 'factory',
#  486: 'consider',
#  487: 'potential',
#  488: 'mean',
#  489: 'international',
#  490: 'develop',
#  491: 'china',
#  492: 'plug',
#  493: 'vue',
#  494: 'advantage',
#  495: 'recent',
#  496: 'benchmark',
#  497: 'import',
#  498: 'kong',
#  499: 'vote',
#  500: 'pound',
#  501: 'vikings',
#  502: 'bears',
#  503: 'regulation',
#  504: 'thank',
#  505: 'lot',
#  506: 'stand',
#  507: 'giant',
#  508: 'television',
#  509: 'account',
#  510: 'electronics',
#  511: 'manager',
#  512: 'package',
#  513: 'chicago',
#  514: 'commission',
#  515: 'conclude',
#  516: 'internet',
#  517: 'partner',
#  518: 'begin',
#  519: 'warn',
#  520: 'radio',
#  521: 'actually',
#  522: 'london',
#  523: 'saudi',
#  524: 'seek',
#  525: 'alternative',
#  526: 'gold',
#  527: 'majority',
#  528: 'personal',
#  529: 'situation',
#  530: 'later',
#  531: 'thing',
#  532: 'check',
#  533: 'war',
#  534: 'particularly',
#  535: 'involve',
#  536: 'court',
#  537: 'rule',
#  538: 'americans',
#  539: 'bear',
#  540: 'surprise',
#  541: 'feel',
#  542: 'ask',
#  543: 'management',
#  544: 'engine',
#  545: 'times',
#  546: 'mark',
#  547: 'write',
#  548: 'federated',
#  549: 'rest',
#  550: 'medium',
#  551: 'customer',
#  552: 'steep',
#  553: 'treasury',
#  554: 'yield',
#  555: 'condition',
#  556: 'nokia',
#  557: 'operate',
#  558: 'mobile',
#  559: 'jet',
#  560: 'compete',
#  561: 'asset',
#  562: 'barclays',
#  563: 'indicator',
#  564: 'pass',
#  565: 'tight',
#  566: 'family',
#  567: 'player',
#  568: 'near',
#  569: 'nfl',
#  570: 'build',
#  571: 'pick',
#  572: 'happen',
#  573: 'eye',
#  574: 'subscriber',
#  575: 'rebound',
#  576: 'exclude',
#  577: 'matter',
#  578: 'unemployment',
#  579: 'wage',
#  580: 'development',
#  581: 'emerge',
#  582: 'rally',
#  583: 'finally',
#  584: 'drive',
#  585: 'car',
#  586: 'guidance',
#  587: 'pengrowth',
#  588: 'acquisition',
#  589: 'nikkei',
#  590: 'standard',
#  591: 'advance',
#  592: 'lcd',
#  593: 'single',
#  594: 'citigroup',
#  595: 'series',
#  596: 'suggest',
#  597: 'broker',
#  598: 'tax',
#  599: 'kerkorian',
#  600: 'pork',
#  601: 'disappointing',
#  602: 'cheesecake',
#  603: 'mall',
#  604: 'date',
#  605: 'traffic',
#  606: 'option',
#  607: 'available',
#  608: 'separate',
#  609: 'strategy',
#  610: 'addition',
#  611: 'best',
#  612: 'answer',
#  613: 'shipping',
#  614: 'popular',
#  615: 'declare',
#  616: 'experience',
#  617: 'return',
#  618: 'network',
#  619: 'handle',
#  620: 'legal',
#  621: 'black',
#  622: 'baby',
#  623: 'win',
#  624: 'apple',
#  625: 'room',
#  626: 'reverse',
#  627: 'organization',
#  628: 'prospect',
#  629: 'yen',
#  630: 'buyer',
#  631: 'chain',
#  632: 'catalogue',
#  633: 'promise',
#  634: 'household',
#  635: 'position',
#  636: 'confirm',
#  637: 'information',
#  638: 'explain',
#  639: 'law',
#  640: 'suffer',
#  641: 'appeal',
#  642: 'advertising',
#  643: 'light',
#  644: 'willing',
#  645: 'anticipate',
#  646: 'managing',
#  647: 'better',
#  648: 'content',
#  649: 'cheer',
#  650: 'google',
#  651: 'ad',
#  652: 'san',
#  653: 'tech',
#  654: 'manufacture',
#  655: 'clue',
#  656: 'comparison',
#  657: 'view',
#  658: 'goldman',
#  659: 'los',
#  660: 'angeles',
#  661: 'download',
#  662: 'dominate',
#  663: 'death',
#  664: 'competitive',
#  665: 'departments',
#  666: 'realtors',
#  667: 'lend',
#  668: 'upside',
#  669: 'summary',
#  670: 'preliminary',
#  671: 'kongs',
#  672: 'hang',
#  673: 'seng',
#  674: 'competitor',
#  675: 'delay',
#  676: 'version',
#  677: 'billionaire',
#  678: 'realty',
#  679: 'trust',
#  680: 'consensus',
#  681: 'gradually',
#  682: 'substantial',
#  683: 'possible',
#  684: 'process',
#  685: 'ceo',
#  686: 'steady',
#  687: 'asia',
#  688: 'prove',
#  689: 'tear',
#  690: 'washington',
#  691: 'pretty',
#  692: 'warning',
#  693: 'message',
#  694: 'trim',
#  695: 'consistent',
#  696: 'automotive',
#  697: 'healthy',
#  698: 'deutsche',
#  699: 'tillman',
#  700: 'foundation',
#  701: 'resource',
#  702: 'love',
#  703: 'landing',
#  704: 'old',
#  705: 'merrill',
#  706: 'problem',
#  707: 'satellite',
#  708: 'put',
#  709: 'residential',
#  710: 'adjustment',
#  711: 'wrong',
#  712: 'cause',
#  713: 'equivalent',
#  714: 'program',
#  715: 'ifc',
#  716: 'transaction',
#  717: 'south',
#  718: 'dip',
#  719: 'blog',
#  720: 'member',
#  721: 'saturn',
#  722: 'wagoner',
#  723: 'premium',
#  724: 'companys',
#  725: 'reduce',
#  726: 'cautious',
#  727: 'offset',
#  728: 'current',
#  729: 'bolster',
#  730: 'extend',
#  731: 'stage',
#  732: 'country',
#  733: 'link',
#  734: 'journal',
#  735: 'unexpectedly',
#  736: 'draw',
#  737: 'change',
#  738: 'employment',
#  739: 'recession',
#  740: 'buyout',
#  741: 'match',
#  742: 'fix',
#  743: 'peak',
#  744: 'pcrd',
#  745: 'foreign',
#  746: 'block',
#  747: 'costco',
#  748: 'bit',
#  749: 'warm',
#  750: 'heinz',
#  751: 'dolphins',
#  752: 'sure',
#  753: 'inflatable',
#  754: 'hog',
#  755: 'dealer',
#  756: 'borrowing',
#  757: 'interested',
#  758: 'depend',
#  759: 'operating',
#  760: 'office',
#  761: 'conduct',
#  762: 'vice',
#  763: 'circuit',
#  764: 'heavy',
#  765: 'purchase',
#  766: 'item',
#  767: 'plasma',
#  768: 'cell',
#  769: 'console',
#  770: 'challenge',
#  771: 'kind',
#  772: 'brick',
#  773: 'join',
#  774: 'web',
#  775: 'jump',
#  776: 'acquire',
#  777: 'center',
#  778: 'ups',
#  779: 'visit',
#  780: 'plant',
#  781: 'delivery',
#  782: 'ebay',
#  783: 'let',
#  784: 'plenty',
#  785: 'trouble',
#  786: 'yuletide',
#  787: 'rush',
#  788: 'computers',
#  789: 'ipod',
#  790: 'living',
#  791: 'root',
#  792: 'minister',
#  793: 'slide',
#  794: 'uncertainty',
#  795: 'gmt',
#  796: 'reduction',
#  797: 'underpin',
#  798: 'act',
#  799: 'reporter',
#  800: 'resume',
#  801: 'reason',
#  802: 'largely',
#  803: 'own',
#  804: 'respectively',
#  805: 'penney',
#  806: 'exception',
#  807: 'portfolio',
#  808: 'different',
#  809: 'seller',
#  810: 'wish',
#  811: 'pier',
#  812: 'upscale',
#  813: 'kid',
#  814: 'what',
#  815: 'youtube',
#  816: 'certain',
#  817: 'draizen',
#  818: 'relationship',
#  819: 'search',
#  820: 'thought',
#  821: 'complete',
#  822: 'generation',
#  823: 'francisco',
#  824: 'rating',
#  825: 'middle',
#  826: 'debate',
#  827: 'digit',
#  828: 'blue',
#  829: 'chip',
#  830: 'sluggish',
#  831: 'downward',
#  832: 'final',
#  833: 'idea',
#  834: 'certainly',
#  835: 'throw',
#  836: 'finish',
#  837: 'sachs',
#  838: 'movie',
#  839: 'studio',
#  840: 'definition',
#  841: 'model',
#  842: 'fight',
#  843: 'segment',
#  844: 'anytime',
#  845: 'trader',
#  846: 'heel',
#  847: 'bag',
#  848: 'slight',
#  849: 'productivity',
#  850: 'deliver',
#  851: 'previously',
#  852: 'independent',
#  853: 'shares',
#  854: 'collateral',
#  855: 'direction',
#  856: 'forward',
#  857: 'possibility',
#  858: 'monitor',
#  859: 'lauder',
#  860: 'wii',
#  861: 'arm',
#  862: 'fear',
#  863: 'reform',
#  864: 'repeat',
#  865: 'scenario',
#  866: 'basis',
#  867: 'employee',
#  868: 'maintain',
#  869: 'reaction',
#  870: 'wealth',
#  871: 'monetary',
#  872: 'ride',
#  873: 'kill',
#  874: 'surprised',
#  875: 'apparently',
#  876: 'section',
#  877: 'try',
#  878: 'fashion',
#  879: 'style',
#  880: 'invest',
#  881: 'stuff',
#  882: 'location',
#  883: 'environment',
#  884: 'yesterday',
#  885: 'coverage',
#  886: 'wonder',
#  887: 'describe',
#  888: 'decision',
#  889: 'catch',
#  890: 'banker',
#  891: 'name',
#  892: 'leader',
#  893: 'provider',
#  894: 'comcast',
#  895: 'tivos',
#  896: 'example',
#  897: 'ultimately',
#  898: 'deceleration',
#  899: 'prepared',
#  900: 'remark',
#  901: 'rapidly',
#  902: 'bet',
#  903: 'history',
#  904: 'building',
#  905: 'builder',
#  906: 'unsold',
#  907: 'limited',
#  908: 'extra',
#  909: 'banks',
#  910: 'professor',
#  911: 'school',
#  912: 'lynch',
#  913: 'financing',
#  914: 'loan',
#  915: 'finance',
#  916: 'approve',
#  917: 'involvement',
#  918: 'conference',
#  919: 'double',
#  920: 'previous',
#  921: 'heat',
#  922: 'tend',
#  923: 'disc',
#  924: 'motors',
#  925: 'electric',
#  926: 'battery',
#  927: 'toyota',
#  928: 'north',
#  929: 'express',
#  930: 'truck',
#  931: 'significant',
#  932: 'clearly',
#  933: 'word',
#  934: 'comfort',
#  935: 'asian',
#  936: 'taiwans',
#  937: 'australian',
#  938: 'approach',
#  939: 'british',
#  940: 'familiar',
#  941: 'top',
#  942: 'revise',
#  943: 'mix',
#  944: 'initial',
#  945: 'kyodo',
#  946: 'panel',
#  947: 'pull',
#  948: 'samsung',
#  949: 'attractive',
#  950: 'tie',
#  951: 'cash',
#  952: 'attract',
#  953: 'broadcast',
#  954: 'recently',
#  955: 'pfizers',
#  956: 'wachovia',
#  957: 'picture',
#  958: 'adjust',
#  959: 'brothers',
#  960: 'slip',
#  961: 'analysis',
#  962: 'occur',
#  963: 'markets',
#  964: 'unexpected',
#  965: 'exxon',
#  966: 'jobless',
#  967: 'claim',
#  968: 'ftse',
#  969: 'german',
#  970: 'performance',
#  971: 'carrier',
#  972: 'lis',
#  973: 'father',
#  974: 'beijing',
#  975: 'australias',
#  976: 'instead',
#  977: 'korea',
#  978: 'showing',
#  979: 'barometer',
#  980: 'export',
#  981: 'streets',
#  982: 'cpi',
#  983: 'kohls',
#  984: 'range',
#  985: 'expense',
#  986: 'raiders',
#  987: 'pipeline',
#  988: 'evidence',
#  989: 'viking',
#  990: 'agent',
#  991: 'litigation',
#  992: 'philips',
#  993: 'oklahoma',
#  994: 'corn',
#  995: 'feed',
#  996: 'tighten',
#  997: 'bernard',
#  998: 'sands',
#  999: 'exceed',
#  1000: 'restaurant',
#  ...}

# %% [markdown]
# Find the longest string for padding:

# %%
max_length = max([len(doc.split()) for doc in train_docs1])
print(max_length)

xtrain_docs = pad_sequences(sequences, maxlen=max_length, padding='post')
# Out:
# 3565

# %% [markdown]
# Print the one-hot encoded dataframe:

# %%
pd.DataFrame(xtrain_docs)

# %% [markdown]
# The vocabulary size is the total number of words in our vocabulary, plus one for unknown words:

# %%
# define vocabulary size (largest integer value)
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 2983

# %% [markdown]
# Define the neural network model:
#
# We use just 1 output node for the classification since we use the sigmoid activivation function which will just return the predicted value.
#
# Alternatively, You could create a neural network with two output nodes, one for each sex, and use softmax activation so that the outputs sum to 1.0 and could be interpreted as probabilities. For example if output node 0 is male and output node 1 is female, and the neural network output values are 0.75 and 0.25, you’d conclude the person is a male.
#
# On the other hand, you could create a neural network with just one output node, and use log-sigmoid activation so that the single output, which will be between 0 and 1, represents the probability of just one of the two classes (say, male). So if the output was 0.44, you’d infer the probability of male is 0.44 and therefore the probability of female is 0.56 and conclude the person is female.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=max_length))
model.add(LSTM(kernel_size=8, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-218-9ab0002a7ecb> in <module>
#       1 # define model
#       2 model = Sequential()
# ----> 3 model.add(Embedding(vocab_size, 100, input_length=max_length))
#       4 model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
#       5 model.add(MaxPooling1D(pool_size=2))
#
# ~\Anaconda3\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     164                     # and create the node connecting the current layer
#     165                     # to the input layer we just created.
# --> 166                     layer(x)
#     167                     set_inputs = True
#     168             else:
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     444                 # Raise exceptions in case the input is not compatible
#     445                 # with the input_spec specified in the layer constructor.
# --> 446                 self.assert_input_compatibility(inputs)
#     447
#     448                 # Collect input shapes to build layer.
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in assert_input_compatibility(self, inputs)
#     308         for x in inputs:
#     309             try:
# --> 310                 K.is_keras_tensor(x)
#     311             except ValueError:
#     312                 raise ValueError('Layer ' + self.name + ' was called with '
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in is_keras_tensor(x)
#     693     ```
#     694     """
# --> 695     if not is_tensor(x):
#     696         raise ValueError('Unexpectedly found an instance of type `' +
#     697                          str(type(x)) + '`. '
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in is_tensor(x)
#     701
#     702 def is_tensor(x):
# --> 703     return isinstance(x, tf_ops._TensorLike) or tf_ops.is_dense_tensor_like(x)
#     704
#     705
#
# AttributeError: module 'tensorflow.python.framework.ops' has no attribute '_TensorLike'

# %%
# fit the model
model.fit(xtrain_docs, labels, epochs=50, verbose=0)
# evaluate the model
loss, accuracy = model.evaluate(xtrain_docs, labels, verbose=0)
print('Accuracy: %f' % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6242a9f9be4> in <module>
#       1 # fit the model
# ----> 2 model.fit(xtrain_docs, labels, epochs=50, verbose=0)
#       3 # evaluate the model
#       4 loss, accuracy = model.evaluate(xtrain_docs, labels, verbose=0)
#       5 print('Accuracy: %f' % (accuracy*100))
#
# NameError: name 'model' is not defined
